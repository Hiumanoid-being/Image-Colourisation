# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from pathlib import Path

# %%
ray_path = Path("../data/processed_subset/places365/train/grayscale/some_image.jpg")
color_path = Path("../data/processed_subset/places365/train/color/some_image.npy")

L = np.array(Image.open(gray_path)) / 255.0
AB = np.load(color_path)

# Reconstruct LAB image for visualization
LAB = np.zeros((256, 256, 3))
LAB[:, :, 0] = L * 255
LAB[:, :, 1:] = AB * 128 + 128

rgb = Image.fromarray(LAB.astype(np.uint8), mode="LAB").convert("RGB")

plt.subplot(1, 2, 1)
plt.imshow(L, cmap="gray")
plt.title("Grayscale Input")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(rgb)
plt.title("Reconstructed Color Image")
plt.axis("off")

plt.show()
